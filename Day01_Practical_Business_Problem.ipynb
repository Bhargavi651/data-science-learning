# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavi651/data-science-learning/blob/main/Day01_Practical_Business_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 1 Practical

Business Problem to Data Solution

# %%
import pandas as pd

# %%
data = {
    "Customer": ["A", "B", "C", "D", "E"],
    "Age": [22, 35, 28, 45, 31],
    "Monthly Spend": [500, 1200, 800, 1800, 950],
    "Complaints": [0, 4, 1, 5, 2],
    "Churn": ["No", "Yes", "No", "Yes", "No"]
}

df = pd.DataFrame(data)

df

# %%
# Practical Questions

# %%
## 1. Business Problem

The company is experiencing customer churn and wants to understand why customers are leaving so that appropriate retention strategies can be implemented.

# %%
## 2. Target Variable

Target Variable

- Churn

Features

- Age
- Monthly Spend
- Complaints

Customer ID is only an identifier and is not used as a feature.

# %%
## 3. Data Science Lifecycle

Business Problem
- Customers are leaving the company.

Collect Data
- Collect customer age, monthly spending, complaints and churn history.

EDA
- Explore relationships between complaints, spending and churn.

Feature Engineering
- Prepare useful features such as complaint frequency or encoded categorical values.

Model Building
- Train a classification model such as Logistic Regression or Decision Tree.

Evaluation
- Evaluate using Accuracy, Precision, Recall and F1-score.

Deployment
- Predict customers likely to churn and help the business take preventive actions.

# %%
## 4. Business Recommendation

Customers with a high number of complaints appear more likely to leave. The company should:

- Prioritize complaint resolution.
- Improve customer support response time.
- Follow up with dissatisfied customers.
- Offer retention incentives for high-risk customers.

# %%
# Reflection

Today I learned:

- Data Science focuses on solving business problems using data.
- Every project starts with a business problem.
- Data Science follows a structured lifecycle.
- Machine Learning is only one part of Data Science.
- Before building a model, it is important to understand the business problem and the available data.
